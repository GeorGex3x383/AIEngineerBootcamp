# %%
pip uninstall -y numpy spacy thinc
# Out:
# Found existing installation: numpy 2.2.6
# Uninstalling numpy-2.2.6:
#   Successfully uninstalled numpy-2.2.6
# Found existing installation: spacy 3.8.7
# Uninstalling spacy-3.8.7:
#   Successfully uninstalled spacy-3.8.7
# Found existing installation: thinc 8.3.6
# Uninstalling thinc-8.3.6:
#   Successfully uninstalled thinc-8.3.6
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\jemil\anaconda3\Lib\site-packages\~hinc'.
# You can safely remove it manually.

# %% [markdown]
# Practical case from Section 22_NLP Module: Identifying Parts of Speech and Named Entities

# %%
pip install numpy==1.26.4 spacy==3.7.4
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# ...
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# ...
#    ---------------------------------------- 0.0/11.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.7 MB 653.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.7 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.2/11.7 MB 1.3 MB/s eta 0:00:09
#     --------------------------------------- 0.2/11.7 MB 1.3 MB/s eta 0:00:10
#     --------------------------------------- 0.3/11.7 MB 1.3 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/11.7 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/11.7 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/11.7 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/11.7 MB 1.3 MB/s eta 0:00:09
# ...

# %%
# !pip uninstall -y spacy pydantic
# !pip install "spacy==3.7.4" "pydantic<2"
# Out:
# Found existing installation: spacy 3.7.4
# Uninstalling spacy-3.7.4:
#   Successfully uninstalled spacy-3.7.4
# Found existing installation: pydantic 2.5.3
# Uninstalling pydantic-2.5.3:
#   Successfully uninstalled pydantic-2.5.3
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\jemil\anaconda3\Lib\site-packages\~pacy'.
# You can safely remove it manually.
# ...
#   Using cached spacy-3.7.4-cp312-cp312-win_amd64.whl.metadata (27 kB)
# ...
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/155.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/155.5 kB ? eta -:--:--
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
import spacy

# %%
bbc_data = pd.read_csv("bbc_news.csv") # the data should be in the same folder as your notebook
